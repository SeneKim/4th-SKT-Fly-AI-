# %% [markdown]
# ## MNIST 데이터 학습

# %%
import tensorflow as tf

# 1. MNIST 데이터셋 임포트
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# 2. 데이터 전처리
x_train, x_test = x_train/255.0, x_test/255.0

# 3. 모델 구성
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(512, activation=tf.nn.relu),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

# 4. 모델 컴파일
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# 5. 모델 훈련
model.fit(x_train, y_train, epochs=15)

# 6. 정확도 평가
test_loss, test_acc = model.evaluate(x_test, y_test)
print('테스트 정확도:', test_acc)
# Out:
# Epoch 1/15
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.1983 - accuracy: 0.9418
# Epoch 2/15
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0792 - accuracy: 0.9761
# Epoch 3/15
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0526 - accuracy: 0.9835
# Epoch 4/15
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0355 - accuracy: 0.9888
# Epoch 5/15
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0277 - accuracy: 0.9911
# Epoch 6/15
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0216 - accuracy: 0.9930
# Epoch 7/15
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0167 - accuracy: 0.9944
# Epoch 8/15
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0133 - accuracy: 0.9958
# Epoch 9/15
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0117 - accuracy: 0.9959
# Epoch 10/15
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0117 - accuracy: 0.9962
# Epoch 11/15
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0106 - accuracy: 0.9965
# Epoch 12/15
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0079 - accuracy: 0.9975
# Epoch 13/15
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0081 - accuracy: 0.9972
# Epoch 14/15
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0078 - accuracy: 0.9972
# Epoch 15/15
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0084 - accuracy: 0.9972
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1032 - accuracy: 0.9800
# 테스트 정확도: 0.9800000190734863

# %% [markdown]
# ## fashion-MNIST 학습

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import fashion_mnist

# %%
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# 정규화
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
model = Sequential([
  Flatten(input_shape=(28, 28)),
  Dense(128, activation='relu'),
  Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4968 - accuracy: 0.8250
# Epoch 2/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3744 - accuracy: 0.8651
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3365 - accuracy: 0.8775
# Epoch 4/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3106 - accuracy: 0.8855
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2942 - accuracy: 0.8914
# Epoch 6/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2794 - accuracy: 0.8963
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2685 - accuracy: 0.8994
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2586 - accuracy: 0.9043
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2473 - accuracy: 0.9083
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2384 - accuracy: 0.9096

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 0.3483 - accuracy: 0.8753 - 554ms/epoch - 2ms/step
#
# Test accuracy: 0.8752999901771545

# %%
import zipfile
import os

# 압축 해제할 파일 경로
zip_path = '/content/shapes.zip'

# 압축 해제될 디렉토리 경로 (변경 가능)
extract_path = '/content/shapes'

# 디렉토리 생성 (없을 경우)
if not os.path.exists(extract_path):
    os.makedirs(extract_path)

# 압축 해제
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print('압축 해제 완료')
# Out:
# 압축 해제 완료

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# 이미지 데이터 생성기 인스턴스화
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_generator = train_datagen.flow_from_directory(
    '/content/shapes/shapes',
    target_size=(28, 28),
    batch_size=32,
    class_mode='categorical',
    subset='training')

validation_generator = train_datagen.flow_from_directory(
    '/content/shapes/shapes',
    target_size=(28, 28),
    batch_size=32,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 240 images belonging to 3 classes.
# Found 60 images belonging to 3 classes.

# %%
model = Sequential([
    Flatten(input_shape=(28, 28, 3)),  # 3 채널 이미지를 위한 입력 형태 조정
    Dense(128, activation='relu'),
    Dense(3, activation='softmax')  # 클래스가 3개이므로 뉴런 수를 3으로 설정
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',  # 다중 분류를 위한 손실 함수 변경
              metrics=['accuracy'])

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
    epochs=10)
# Out:
# Epoch 1/10
# 7/7 [==============================] - 1s 53ms/step - loss: 5.5738 - accuracy: 0.2692 - val_loss: 1.6805 - val_accuracy: 0.3125
# Epoch 2/10
# 7/7 [==============================] - 0s 23ms/step - loss: 1.3090 - accuracy: 0.3510 - val_loss: 1.5057 - val_accuracy: 0.3125
# Epoch 3/10
# 7/7 [==============================] - 0s 24ms/step - loss: 1.3360 - accuracy: 0.2692 - val_loss: 1.3999 - val_accuracy: 0.2188
# Epoch 4/10
# 7/7 [==============================] - 0s 28ms/step - loss: 1.1436 - accuracy: 0.3365 - val_loss: 1.0994 - val_accuracy: 0.3125
# Epoch 5/10
# 7/7 [==============================] - 0s 24ms/step - loss: 1.0994 - accuracy: 0.3077 - val_loss: 1.0987 - val_accuracy: 0.3125
# Epoch 6/10
# 7/7 [==============================] - 0s 23ms/step - loss: 1.0986 - accuracy: 0.3438 - val_loss: 1.0989 - val_accuracy: 0.3125
# Epoch 7/10
# 7/7 [==============================] - 0s 22ms/step - loss: 1.0987 - accuracy: 0.3269 - val_loss: 1.0990 - val_accuracy: 0.2812
# Epoch 8/10
# 7/7 [==============================] - 0s 21ms/step - loss: 1.0986 - accuracy: 0.3269 - val_loss: 1.0992 - val_accuracy: 0.2500
# Epoch 9/10
# 7/7 [==============================] - 0s 27ms/step - loss: 1.0986 - accuracy: 0.3304 - val_loss: 1.0988 - val_accuracy: 0.2812
# Epoch 10/10
# 7/7 [==============================] - 0s 27ms/step - loss: 1.0984 - accuracy: 0.3558 - val_loss: 1.0993 - val_accuracy: 0.2500

# %%
# 검증 데이터셋에 대한 모델 평가
val_loss, val_acc = model.evaluate(validation_generator)
print('Validation accuracy:', val_acc)
# Out:
# 2/2 [==============================] - 0s 15ms/step - loss: 1.0986 - accuracy: 0.3333
# Validation accuracy: 0.3333333432674408

# %% [markdown]
# ## shapes attempt2

# %%
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout


# 데이터 로드 및 전처리
data_dir = '/content/shapes/shapes'
batch_size = 32
img_height = 180
img_width = 180

train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)
train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training')

validation_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation')

model = Sequential([
    # 첫 번째 컨볼루션 블록
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)),
    MaxPooling2D(2, 2),

    # 두 번째 컨볼루션 블록
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    # 세 번째 컨볼루션 블록
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    # 네 번째 컨볼루션 블록
    Conv2D(256, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    # Flatten 및 완전 연결 레이어
    Flatten(),
    Dense(256, activation='relu'),
    Dense(3, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 모델 훈련 및 평가
history = model.fit(train_generator, epochs=100, batch_size=16, validation_data=validation_generator)

# 모델 저장 (선택적)
model.save('shapes_model_deeper.h5')
# Out:
# Found 240 images belonging to 3 classes.
# Found 60 images belonging to 3 classes.
# Epoch 1/100
# 8/8 [==============================] - 3s 126ms/step - loss: 1.6413 - accuracy: 0.3375 - val_loss: 1.0989 - val_accuracy: 0.3333
# Epoch 2/100
# 8/8 [==============================] - 1s 66ms/step - loss: 1.1023 - accuracy: 0.3250 - val_loss: 1.0989 - val_accuracy: 0.3333
# Epoch 3/100
# 8/8 [==============================] - 0s 57ms/step - loss: 1.1013 - accuracy: 0.2958 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 4/100
# 8/8 [==============================] - 0s 57ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 5/100
# 8/8 [==============================] - 0s 58ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 6/100
# 8/8 [==============================] - 1s 69ms/step - loss: 1.0989 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 7/100
# 8/8 [==============================] - 0s 57ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 8/100
# 8/8 [==============================] - 0s 60ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 9/100
# 8/8 [==============================] - 0s 57ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 10/100
# 8/8 [==============================] - 0s 58ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 11/100
# 8/8 [==============================] - 0s 58ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 12/100
# 8/8 [==============================] - 0s 58ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 13/100
# 8/8 [==============================] - 0s 59ms/step - loss: 1.0987 - accuracy: 0.3042 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 14/100
# 8/8 [==============================] - 0s 59ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 15/100
# 8/8 [==============================] - 0s 57ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 16/100
# 8/8 [==============================] - 0s 59ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 17/100
# 8/8 [==============================] - 0s 60ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 18/100
# 8/8 [==============================] - 1s 75ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 19/100
# 8/8 [==============================] - 0s 59ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 20/100
# 8/8 [==============================] - 1s 72ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 21/100
# 8/8 [==============================] - 1s 67ms/step - loss: 1.0988 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 22/100
# 8/8 [==============================] - 1s 77ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 23/100
# 8/8 [==============================] - 1s 60ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 24/100
# 8/8 [==============================] - 0s 59ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 25/100
# 8/8 [==============================] - 0s 60ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 26/100
# 8/8 [==============================] - 0s 58ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 27/100
# 8/8 [==============================] - 0s 58ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 28/100
# 8/8 [==============================] - 0s 60ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 29/100
# 8/8 [==============================] - 0s 59ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 30/100
# 8/8 [==============================] - 0s 58ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 31/100
# 8/8 [==============================] - 0s 58ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 32/100
# 8/8 [==============================] - 1s 70ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 33/100
# 8/8 [==============================] - 0s 59ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 34/100
# 8/8 [==============================] - 1s 69ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 35/100
# 8/8 [==============================] - 1s 69ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 36/100
# 8/8 [==============================] - 0s 58ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 37/100
# 8/8 [==============================] - 0s 59ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 38/100
# 8/8 [==============================] - 1s 69ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 39/100
# 8/8 [==============================] - 0s 58ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 40/100
# 8/8 [==============================] - 0s 57ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 41/100
# 8/8 [==============================] - 1s 72ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 42/100
# 8/8 [==============================] - 1s 67ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 43/100
# 8/8 [==============================] - 1s 73ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 44/100
# 8/8 [==============================] - 1s 76ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 45/100
# 8/8 [==============================] - 1s 80ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 46/100
# 8/8 [==============================] - 0s 59ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 47/100
# 8/8 [==============================] - 0s 58ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 48/100
# 8/8 [==============================] - 1s 67ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 49/100
# 8/8 [==============================] - 0s 59ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 50/100
# 8/8 [==============================] - 0s 59ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 51/100
# 8/8 [==============================] - 0s 57ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 52/100
# 8/8 [==============================] - 0s 59ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 53/100
# 8/8 [==============================] - 0s 59ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 54/100
# 8/8 [==============================] - 0s 59ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 55/100
# 8/8 [==============================] - 1s 66ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 56/100
# 8/8 [==============================] - 0s 57ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 57/100
# 8/8 [==============================] - 0s 61ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 58/100
# 8/8 [==============================] - 1s 68ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 59/100
# 8/8 [==============================] - 0s 57ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 60/100
# 8/8 [==============================] - 0s 59ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 61/100
# 8/8 [==============================] - 1s 61ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 62/100
# 6/8 [=====================>........] - ETA: 0s - loss: 1.0987 - accuracy: 0.3295
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-8e2c6c9c628e> in <cell line: 57>()
#      55
#      56 # 모델 훈련 및 평가
# ---> 57 history = model.fit(train_generator, epochs=100, batch_size=16, validation_data=validation_generator)
#      58
#      59 # 모델 저장 (선택적)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1805                         ):
#    1806                             callbacks.on_train_batch_begin(step)
# -> 1807                             tmp_logs = self.train_function(iterator)
#    1808                             if data_handler.should_sync:
#    1809                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     830
#     831       with OptionalXlaContext(self._jit_compile):
# --> 832         result = self._call(*args, **kwds)
#     833
#     834       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     866       # In this case we have created variables on the first call, so we run the
#     867       # defunned version which is guaranteed to never create variables.
# --> 868       return tracing_compilation.call_function(
#     869           args, kwds, self._no_variable_creation_config
#     870       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1321         and executing_eagerly):
#    1322       # No tape is watching; skip to running the function.
# -> 1323       return self._inference_function.call_preflattened(args)
#    1324     forward_backward = self._select_forward_and_backward_functions(
#    1325         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1484     cancellation_context = cancellation.context()
#    1485     if cancellation_context is None:
# -> 1486       outputs = execute.execute(
#    1487           name.decode("utf-8"),
#    1488           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout


# 데이터 로드 및 전처리
data_dir = '/content/shapes/shapes'
batch_size = 32
img_height = 180
img_width = 180

train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)
train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training')

validation_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation')

model = Sequential([
    # 첫 번째 컨볼루션 블록
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)),
    MaxPooling2D(2, 2),

    # 두 번째 컨볼루션 블록
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    # 세 번째 컨볼루션 블록
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    # 네 번째 컨볼루션 블록
    Conv2D(256, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    # Flatten 및 완전 연결 레이어
    Flatten(),
    Dense(256, activation='relu'),
    Dense(3, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 모델 훈련 및 평가
history = model.fit(train_generator, epochs=100, batch_size=32, validation_data=validation_generator)

# 모델 저장 (선택적)
model.save('shapes_model_deeper.h5')
# Out:
# Found 240 images belonging to 3 classes.
# Found 60 images belonging to 3 classes.
# Epoch 1/100
# 8/8 [==============================] - 3s 109ms/step - loss: 1.6146 - accuracy: 0.3125 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 2/100
# 8/8 [==============================] - 0s 64ms/step - loss: 1.1047 - accuracy: 0.3333 - val_loss: 1.0983 - val_accuracy: 0.3333
# Epoch 3/100
# 8/8 [==============================] - 1s 58ms/step - loss: 1.0999 - accuracy: 0.3250 - val_loss: 1.0978 - val_accuracy: 0.3333
# Epoch 4/100
# 8/8 [==============================] - 1s 61ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0979 - val_accuracy: 0.3333
# Epoch 5/100
# 8/8 [==============================] - 0s 59ms/step - loss: 1.0981 - accuracy: 0.3250 - val_loss: 1.0949 - val_accuracy: 0.4833
# Epoch 6/100
# 8/8 [==============================] - 1s 61ms/step - loss: 1.0935 - accuracy: 0.4000 - val_loss: 1.0797 - val_accuracy: 0.4333
# Epoch 7/100
# 8/8 [==============================] - 0s 59ms/step - loss: 1.0636 - accuracy: 0.4542 - val_loss: 1.0143 - val_accuracy: 0.4667
# Epoch 8/100
# 8/8 [==============================] - 1s 68ms/step - loss: 1.0128 - accuracy: 0.4625 - val_loss: 0.9482 - val_accuracy: 0.4667
# Epoch 9/100
# 8/8 [==============================] - 0s 58ms/step - loss: 0.9788 - accuracy: 0.5250 - val_loss: 1.0206 - val_accuracy: 0.5333
# Epoch 10/100
# 8/8 [==============================] - 1s 78ms/step - loss: 0.9348 - accuracy: 0.5750 - val_loss: 0.8731 - val_accuracy: 0.5667
# Epoch 11/100
# 8/8 [==============================] - 1s 69ms/step - loss: 0.8701 - accuracy: 0.5708 - val_loss: 0.8702 - val_accuracy: 0.6167
# Epoch 12/100
# 8/8 [==============================] - 1s 81ms/step - loss: 0.8211 - accuracy: 0.6042 - val_loss: 0.8436 - val_accuracy: 0.6500
# Epoch 13/100
# 8/8 [==============================] - 1s 71ms/step - loss: 0.7484 - accuracy: 0.6625 - val_loss: 0.7156 - val_accuracy: 0.6667
# Epoch 14/100
# 8/8 [==============================] - 1s 82ms/step - loss: 0.6146 - accuracy: 0.7417 - val_loss: 0.6583 - val_accuracy: 0.7333
# Epoch 15/100
# 8/8 [==============================] - 0s 58ms/step - loss: 0.4849 - accuracy: 0.8292 - val_loss: 0.6330 - val_accuracy: 0.7833
# Epoch 16/100
# 8/8 [==============================] - 0s 60ms/step - loss: 0.3203 - accuracy: 0.8542 - val_loss: 0.5031 - val_accuracy: 0.8167
# Epoch 17/100
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1760 - accuracy: 0.9333 - val_loss: 0.7003 - val_accuracy: 0.8000
# Epoch 18/100
# 8/8 [==============================] - 0s 58ms/step - loss: 0.1789 - accuracy: 0.9333 - val_loss: 0.6465 - val_accuracy: 0.7833
# Epoch 19/100
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0954 - accuracy: 0.9625 - val_loss: 0.6715 - val_accuracy: 0.7833
# Epoch 20/100
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0553 - accuracy: 0.9875 - val_loss: 0.7990 - val_accuracy: 0.7833
# Epoch 21/100
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0266 - accuracy: 0.9958 - val_loss: 0.8283 - val_accuracy: 0.8500
# Epoch 22/100
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.9036 - val_accuracy: 0.7667
# Epoch 23/100
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0542 - accuracy: 0.9750 - val_loss: 0.9421 - val_accuracy: 0.8000
# Epoch 24/100
# 8/8 [==============================] - 0s 57ms/step - loss: 0.1211 - accuracy: 0.9542 - val_loss: 1.0548 - val_accuracy: 0.7333
# Epoch 25/100
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0530 - accuracy: 0.9792 - val_loss: 1.0090 - val_accuracy: 0.8000
# Epoch 26/100
# 8/8 [==============================] - 1s 61ms/step - loss: 0.0465 - accuracy: 0.9833 - val_loss: 1.3200 - val_accuracy: 0.7333
# Epoch 27/100
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0564 - accuracy: 0.9833 - val_loss: 1.2648 - val_accuracy: 0.8167
# Epoch 28/100
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 1.1407 - val_accuracy: 0.7833
# Epoch 29/100
# 8/8 [==============================] - 0s 57ms/step - loss: 0.0232 - accuracy: 0.9958 - val_loss: 1.3161 - val_accuracy: 0.8000
# Epoch 30/100
# 8/8 [==============================] - 1s 61ms/step - loss: 0.0119 - accuracy: 0.9958 - val_loss: 1.0938 - val_accuracy: 0.7833
# Epoch 31/100
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0129 - accuracy: 0.9958 - val_loss: 1.1472 - val_accuracy: 0.8333
# Epoch 32/100
# 8/8 [==============================] - 1s 68ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.2500 - val_accuracy: 0.8167
# Epoch 33/100
# 8/8 [==============================] - 1s 67ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.1053 - val_accuracy: 0.8333
# Epoch 34/100
# 8/8 [==============================] - 1s 83ms/step - loss: 0.0099 - accuracy: 0.9958 - val_loss: 1.3161 - val_accuracy: 0.8000
# Epoch 35/100
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.2701 - val_accuracy: 0.8167
# Epoch 36/100
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0085 - accuracy: 0.9958 - val_loss: 1.4712 - val_accuracy: 0.8333
# Epoch 37/100
# 8/8 [==============================] - 0s 58ms/step - loss: 7.9399e-04 - accuracy: 1.0000 - val_loss: 1.4925 - val_accuracy: 0.8167
# Epoch 38/100
# 8/8 [==============================] - 1s 62ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.5118 - val_accuracy: 0.8000
# Epoch 39/100
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.5180 - val_accuracy: 0.7833
# Epoch 40/100
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.5818 - val_accuracy: 0.8000
# Epoch 41/100
# 8/8 [==============================] - 0s 57ms/step - loss: 1.4876e-04 - accuracy: 1.0000 - val_loss: 1.7606 - val_accuracy: 0.8333
# Epoch 42/100
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.7541 - val_accuracy: 0.8333
# Epoch 43/100
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.3554 - val_accuracy: 0.8000
# Epoch 44/100
# 8/8 [==============================] - 1s 67ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.4041 - val_accuracy: 0.8167
# Epoch 45/100
# 8/8 [==============================] - 0s 59ms/step - loss: 2.7992e-04 - accuracy: 1.0000 - val_loss: 1.8753 - val_accuracy: 0.8000
# Epoch 46/100
# 8/8 [==============================] - 1s 72ms/step - loss: 7.5914e-04 - accuracy: 1.0000 - val_loss: 2.0721 - val_accuracy: 0.8000
# Epoch 47/100
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 1.4669 - val_accuracy: 0.8500
# Epoch 48/100
# 8/8 [==============================] - 0s 59ms/step - loss: 3.1390e-04 - accuracy: 1.0000 - val_loss: 1.2873 - val_accuracy: 0.8167
# Epoch 49/100
# 8/8 [==============================] - 0s 63ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.3410 - val_accuracy: 0.8333
# Epoch 50/100
# 8/8 [==============================] - 1s 62ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.4410 - val_accuracy: 0.8333
# Epoch 51/100
# 8/8 [==============================] - 0s 58ms/step - loss: 2.5898e-04 - accuracy: 1.0000 - val_loss: 1.5763 - val_accuracy: 0.8167
# Epoch 52/100
# 8/8 [==============================] - 1s 60ms/step - loss: 0.0072 - accuracy: 0.9958 - val_loss: 1.4742 - val_accuracy: 0.8500
# Epoch 53/100
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0240 - accuracy: 0.9958 - val_loss: 1.2815 - val_accuracy: 0.8500
# Epoch 54/100
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 1.8405 - val_accuracy: 0.8000
# Epoch 55/100
# 8/8 [==============================] - 1s 65ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.3886 - val_accuracy: 0.7833
# Epoch 56/100
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0131 - accuracy: 0.9917 - val_loss: 1.4193 - val_accuracy: 0.8500
# Epoch 57/100
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0074 - accuracy: 0.9958 - val_loss: 1.6702 - val_accuracy: 0.8333
# Epoch 58/100
# 8/8 [==============================] - 1s 65ms/step - loss: 0.0092 - accuracy: 0.9958 - val_loss: 1.5470 - val_accuracy: 0.8000
# Epoch 59/100
# 8/8 [==============================] - 1s 68ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.7120 - val_accuracy: 0.7667
# Epoch 60/100
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.6615 - val_accuracy: 0.7833
# Epoch 61/100
# 8/8 [==============================] - 0s 59ms/step - loss: 4.9004e-04 - accuracy: 1.0000 - val_loss: 1.6164 - val_accuracy: 0.8167
# Epoch 62/100
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.5773 - val_accuracy: 0.8333
# Epoch 63/100
# 8/8 [==============================] - 0s 62ms/step - loss: 2.1651e-04 - accuracy: 1.0000 - val_loss: 1.6217 - val_accuracy: 0.8167
# Epoch 64/100
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.6059 - val_accuracy: 0.8500
# Epoch 65/100
# 8/8 [==============================] - 0s 58ms/step - loss: 2.8558e-04 - accuracy: 1.0000 - val_loss: 1.7916 - val_accuracy: 0.8500
# Epoch 66/100
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0073 - accuracy: 0.9958 - val_loss: 1.1697 - val_accuracy: 0.8167
# Epoch 67/100
# 8/8 [==============================] - 1s 73ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.1409 - val_accuracy: 0.8333
# Epoch 68/100
# 8/8 [==============================] - 1s 74ms/step - loss: 5.1499e-04 - accuracy: 1.0000 - val_loss: 1.4140 - val_accuracy: 0.8333
# Epoch 69/100
# 8/8 [==============================] - 1s 78ms/step - loss: 4.1521e-04 - accuracy: 1.0000 - val_loss: 1.4390 - val_accuracy: 0.8500
# Epoch 70/100
# 8/8 [==============================] - 0s 63ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.4462 - val_accuracy: 0.8500
# Epoch 71/100
# 8/8 [==============================] - 0s 59ms/step - loss: 5.2323e-04 - accuracy: 1.0000 - val_loss: 1.4929 - val_accuracy: 0.8500
# Epoch 72/100
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.4456 - val_accuracy: 0.8500
# Epoch 73/100
# 8/8 [==============================] - 0s 57ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.3253 - val_accuracy: 0.8500
# Epoch 74/100
# 8/8 [==============================] - 1s 68ms/step - loss: 9.6464e-05 - accuracy: 1.0000 - val_loss: 1.3124 - val_accuracy: 0.8500
# Epoch 75/100
# 8/8 [==============================] - 1s 76ms/step - loss: 1.4935e-04 - accuracy: 1.0000 - val_loss: 1.3080 - val_accuracy: 0.8500
# Epoch 76/100
# 8/8 [==============================] - 1s 78ms/step - loss: 1.1196e-04 - accuracy: 1.0000 - val_loss: 1.3070 - val_accuracy: 0.8333
# Epoch 77/100
# 8/8 [==============================] - 0s 60ms/step - loss: 6.8300e-05 - accuracy: 1.0000 - val_loss: 1.3086 - val_accuracy: 0.8500
# Epoch 78/100
# 8/8 [==============================] - 0s 57ms/step - loss: 1.3018e-04 - accuracy: 1.0000 - val_loss: 1.3160 - val_accuracy: 0.8500
# Epoch 79/100
# 8/8 [==============================] - 1s 69ms/step - loss: 5.9224e-05 - accuracy: 1.0000 - val_loss: 1.3290 - val_accuracy: 0.8500
# Epoch 80/100
# 8/8 [==============================] - 1s 69ms/step - loss: 2.2150e-04 - accuracy: 1.0000 - val_loss: 1.3405 - val_accuracy: 0.8333
# Epoch 81/100
# 8/8 [==============================] - 1s 60ms/step - loss: 5.9346e-04 - accuracy: 1.0000 - val_loss: 1.3719 - val_accuracy: 0.8500
# Epoch 82/100
# 8/8 [==============================] - 0s 58ms/step - loss: 4.6044e-05 - accuracy: 1.0000 - val_loss: 1.4059 - val_accuracy: 0.8500
# Epoch 83/100
# 8/8 [==============================] - 0s 58ms/step - loss: 4.0629e-05 - accuracy: 1.0000 - val_loss: 1.4255 - val_accuracy: 0.8500
# Epoch 84/100
# 8/8 [==============================] - 0s 59ms/step - loss: 1.2284e-04 - accuracy: 1.0000 - val_loss: 1.4400 - val_accuracy: 0.8500
# Epoch 85/100
# 8/8 [==============================] - 0s 60ms/step - loss: 3.8801e-05 - accuracy: 1.0000 - val_loss: 1.4419 - val_accuracy: 0.8500
# Epoch 86/100
# 8/8 [==============================] - 1s 70ms/step - loss: 5.5373e-05 - accuracy: 1.0000 - val_loss: 1.4606 - val_accuracy: 0.8500
# Epoch 87/100
# 8/8 [==============================] - 0s 62ms/step - loss: 1.7180e-05 - accuracy: 1.0000 - val_loss: 1.4711 - val_accuracy: 0.8500
# Epoch 88/100
# 8/8 [==============================] - 0s 60ms/step - loss: 2.0981e-05 - accuracy: 1.0000 - val_loss: 1.4678 - val_accuracy: 0.8500
# Epoch 89/100
# 8/8 [==============================] - 0s 60ms/step - loss: 8.7536e-06 - accuracy: 1.0000 - val_loss: 1.4706 - val_accuracy: 0.8500
# Epoch 90/100
# 8/8 [==============================] - 0s 59ms/step - loss: 7.2488e-05 - accuracy: 1.0000 - val_loss: 1.4726 - val_accuracy: 0.8500
# Epoch 91/100
# 8/8 [==============================] - 1s 61ms/step - loss: 2.9667e-05 - accuracy: 1.0000 - val_loss: 1.4680 - val_accuracy: 0.8500
# Epoch 92/100
# 8/8 [==============================] - 0s 60ms/step - loss: 3.3710e-05 - accuracy: 1.0000 - val_loss: 1.4745 - val_accuracy: 0.8500
# Epoch 93/100
# 8/8 [==============================] - 1s 70ms/step - loss: 6.5838e-05 - accuracy: 1.0000 - val_loss: 1.4987 - val_accuracy: 0.8333
# Epoch 94/100
# 8/8 [==============================] - 1s 73ms/step - loss: 3.2719e-05 - accuracy: 1.0000 - val_loss: 1.4657 - val_accuracy: 0.8333
# Epoch 95/100
# 8/8 [==============================] - 1s 76ms/step - loss: 1.7759e-05 - accuracy: 1.0000 - val_loss: 1.4660 - val_accuracy: 0.8333
# Epoch 96/100
# 8/8 [==============================] - 1s 69ms/step - loss: 1.9178e-05 - accuracy: 1.0000 - val_loss: 1.4679 - val_accuracy: 0.8333
# Epoch 97/100
# 8/8 [==============================] - 1s 62ms/step - loss: 1.7644e-05 - accuracy: 1.0000 - val_loss: 1.4742 - val_accuracy: 0.8333
# Epoch 98/100
# 8/8 [==============================] - 0s 64ms/step - loss: 1.3265e-05 - accuracy: 1.0000 - val_loss: 1.4795 - val_accuracy: 0.8333
# Epoch 99/100
# 8/8 [==============================] - 0s 58ms/step - loss: 3.8001e-06 - accuracy: 1.0000 - val_loss: 1.4822 - val_accuracy: 0.8333
# Epoch 100/100
# 8/8 [==============================] - 0s 59ms/step - loss: 1.0516e-05 - accuracy: 1.0000 - val_loss: 1.4865 - val_accuracy: 0.8333

# %%
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout


# 데이터 로드 및 전처리
data_dir = '/content/shapes/shapes'
batch_size = 32
img_height = 180
img_width = 180

train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)
train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training')

validation_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation')

model = Sequential([
    # 첫 번째 컨볼루션 블록
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)),
    MaxPooling2D(2, 2),

    # 두 번째 컨볼루션 블록
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    # 세 번째 컨볼루션 블록
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    # 네 번째 컨볼루션 블록
    Conv2D(256, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    # 네 번째 컨볼루션 블록
    Conv2D(512, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    # Flatten 및 완전 연결 레이어
    Flatten(),
    Dense(512, activation='relu'),
    Dense(3, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 모델 훈련 및 평가
history = model.fit(train_generator, epochs=50, batch_size=32, validation_data=validation_generator)

# 모델 저장 (선택적)
model.save('shapes_model_deeper.h5')
# Out:
# Found 240 images belonging to 3 classes.
# Found 60 images belonging to 3 classes.
# Epoch 1/50
# 8/8 [==============================] - 3s 130ms/step - loss: 1.2836 - accuracy: 0.3125 - val_loss: 1.0994 - val_accuracy: 0.3333
# Epoch 2/50
# 8/8 [==============================] - 1s 61ms/step - loss: 1.1027 - accuracy: 0.3000 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 3/50
# 8/8 [==============================] - 1s 60ms/step - loss: 1.1002 - accuracy: 0.3333 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 4/50
# 8/8 [==============================] - 1s 62ms/step - loss: 1.0988 - accuracy: 0.2750 - val_loss: 1.0985 - val_accuracy: 0.3333
# Epoch 5/50
# 8/8 [==============================] - 1s 61ms/step - loss: 1.1003 - accuracy: 0.3458 - val_loss: 1.0984 - val_accuracy: 0.3333
# Epoch 6/50
# 8/8 [==============================] - 1s 61ms/step - loss: 1.0990 - accuracy: 0.2917 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 7/50
# 8/8 [==============================] - 1s 75ms/step - loss: 1.0991 - accuracy: 0.3042 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 8/50
# 8/8 [==============================] - 1s 80ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 9/50
# 8/8 [==============================] - 1s 89ms/step - loss: 1.0987 - accuracy: 0.3375 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 10/50
# 8/8 [==============================] - 1s 72ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 11/50
# 8/8 [==============================] - 1s 60ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 12/50
# 8/8 [==============================] - 1s 62ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 13/50
# 8/8 [==============================] - 1s 79ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 14/50
# 8/8 [==============================] - 1s 60ms/step - loss: 1.0987 - accuracy: 0.3250 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 15/50
# 8/8 [==============================] - 1s 62ms/step - loss: 1.0987 - accuracy: 0.3375 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 16/50
# 8/8 [==============================] - 1s 64ms/step - loss: 1.0987 - accuracy: 0.3500 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 17/50
# 8/8 [==============================] - 1s 63ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0985 - val_accuracy: 0.3333
# Epoch 18/50
# 8/8 [==============================] - 1s 60ms/step - loss: 1.0985 - accuracy: 0.3333 - val_loss: 1.0983 - val_accuracy: 0.3333
# Epoch 19/50
# 8/8 [==============================] - 1s 64ms/step - loss: 1.0983 - accuracy: 0.3333 - val_loss: 1.0977 - val_accuracy: 0.3667
# Epoch 20/50
# 8/8 [==============================] - 1s 61ms/step - loss: 1.0980 - accuracy: 0.3750 - val_loss: 1.0969 - val_accuracy: 0.3333
# Epoch 21/50
# 8/8 [==============================] - 1s 60ms/step - loss: 1.0980 - accuracy: 0.3542 - val_loss: 1.0958 - val_accuracy: 0.5167
# Epoch 22/50
# 8/8 [==============================] - 1s 63ms/step - loss: 1.0922 - accuracy: 0.3792 - val_loss: 1.0725 - val_accuracy: 0.4500
# Epoch 23/50
# 8/8 [==============================] - 1s 61ms/step - loss: 1.0822 - accuracy: 0.4000 - val_loss: 1.0431 - val_accuracy: 0.4500
# Epoch 24/50
# 8/8 [==============================] - 1s 61ms/step - loss: 1.0749 - accuracy: 0.5083 - val_loss: 1.0497 - val_accuracy: 0.5000
# Epoch 25/50
# 8/8 [==============================] - 1s 61ms/step - loss: 1.0211 - accuracy: 0.4583 - val_loss: 0.9211 - val_accuracy: 0.6000
# Epoch 26/50
# 8/8 [==============================] - 1s 73ms/step - loss: 1.0390 - accuracy: 0.4833 - val_loss: 0.9564 - val_accuracy: 0.6500
# Epoch 27/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.9316 - accuracy: 0.5833 - val_loss: 0.8875 - val_accuracy: 0.6667
# Epoch 28/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.8808 - accuracy: 0.5875 - val_loss: 0.7545 - val_accuracy: 0.7000
# Epoch 29/50
# 8/8 [==============================] - 1s 77ms/step - loss: 0.6910 - accuracy: 0.7042 - val_loss: 0.7449 - val_accuracy: 0.6667
# Epoch 30/50
# 8/8 [==============================] - 1s 69ms/step - loss: 0.6233 - accuracy: 0.7542 - val_loss: 0.5078 - val_accuracy: 0.8667
# Epoch 31/50
# 8/8 [==============================] - 1s 62ms/step - loss: 0.4714 - accuracy: 0.8083 - val_loss: 0.3446 - val_accuracy: 0.9167
# Epoch 32/50
# 8/8 [==============================] - 1s 63ms/step - loss: 0.3486 - accuracy: 0.8458 - val_loss: 0.2882 - val_accuracy: 0.9167
# Epoch 33/50
# 8/8 [==============================] - 1s 70ms/step - loss: 0.2649 - accuracy: 0.9292 - val_loss: 0.2547 - val_accuracy: 0.9167
# Epoch 34/50
# 8/8 [==============================] - 1s 63ms/step - loss: 0.1722 - accuracy: 0.9500 - val_loss: 0.2143 - val_accuracy: 0.9500
# Epoch 35/50
# 8/8 [==============================] - 1s 63ms/step - loss: 0.1071 - accuracy: 0.9583 - val_loss: 0.3886 - val_accuracy: 0.8833
# Epoch 36/50
# 8/8 [==============================] - 1s 62ms/step - loss: 0.0859 - accuracy: 0.9750 - val_loss: 0.2711 - val_accuracy: 0.9000
# Epoch 37/50
# 8/8 [==============================] - 1s 64ms/step - loss: 0.0279 - accuracy: 0.9958 - val_loss: 0.2517 - val_accuracy: 0.9167
# Epoch 38/50
# 8/8 [==============================] - 1s 62ms/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.2283 - val_accuracy: 0.9167
# Epoch 39/50
# 8/8 [==============================] - 1s 65ms/step - loss: 0.0118 - accuracy: 0.9958 - val_loss: 0.2423 - val_accuracy: 0.9333
# Epoch 40/50
# 8/8 [==============================] - 1s 62ms/step - loss: 0.0128 - accuracy: 0.9958 - val_loss: 0.2272 - val_accuracy: 0.9167
# Epoch 41/50
# 8/8 [==============================] - 1s 64ms/step - loss: 0.0194 - accuracy: 0.9875 - val_loss: 0.3130 - val_accuracy: 0.9000
# Epoch 42/50
# 8/8 [==============================] - 1s 63ms/step - loss: 0.0429 - accuracy: 0.9875 - val_loss: 0.2474 - val_accuracy: 0.9333
# Epoch 43/50
# 8/8 [==============================] - 1s 65ms/step - loss: 0.0965 - accuracy: 0.9542 - val_loss: 0.3334 - val_accuracy: 0.9333
# Epoch 44/50
# 8/8 [==============================] - 1s 62ms/step - loss: 0.0683 - accuracy: 0.9833 - val_loss: 0.3574 - val_accuracy: 0.8833
# Epoch 45/50
# 8/8 [==============================] - 1s 63ms/step - loss: 0.0342 - accuracy: 0.9875 - val_loss: 0.2988 - val_accuracy: 0.9167
# Epoch 46/50
# 8/8 [==============================] - 1s 63ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.2644 - val_accuracy: 0.9500
# Epoch 47/50
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.2909 - val_accuracy: 0.8833
# Epoch 48/50
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0075 - accuracy: 0.9958 - val_loss: 0.4499 - val_accuracy: 0.9000
# Epoch 49/50
# 8/8 [==============================] - 1s 88ms/step - loss: 0.0062 - accuracy: 0.9958 - val_loss: 0.3664 - val_accuracy: 0.9000
# Epoch 50/50
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.3494 - val_accuracy: 0.9000

# %%
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout


# 데이터 로드 및 전처리
data_dir = '/content/shapes/shapes'
batch_size = 32
img_height = 180
img_width = 180

train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)
train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training')

validation_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation')

model = Sequential([
    # 첫 번째 컨볼루션 블록
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)),
    MaxPooling2D(2, 2),

    # 두 번째 컨볼루션 블록
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    # 세 번째 컨볼루션 블록
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    # 네 번째 컨볼루션 블록
    Conv2D(256, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    # 다섯 번째 컨볼루션 블록
    Conv2D(512, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    # 여섯 번째 컨볼루션 블록
    Conv2D(1024, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    # Flatten 및 완전 연결 레이어
    Flatten(),
    Dense(1024, activation='relu'),
    Dropout(0.5),
    Dense(3, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 모델 훈련 및 평가
history = model.fit(train_generator, epochs=50, batch_size=32, validation_data=validation_generator)

# 모델 저장 (선택적)
model.save('shapes_model_deeper_and_wider.h5')
# Out:
# Found 240 images belonging to 3 classes.
# Found 60 images belonging to 3 classes.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-5ff042abc4aa> in <cell line: 29>()
#      27     subset='validation')
#      28
# ---> 29 model = Sequential([
#      30     # 첫 번째 컨볼루션 블록
#      31     Conv2D(32, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/trackable/base.py in _method_wrapper(self, *args, **kwargs)
#     202     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     203     try:
# --> 204       result = method(self, *args, **kwargs)
#     205     finally:
#     206       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1018   except errors.InvalidArgumentError as e:
#    1019     # Convert to ValueError for backwards compatibility.
# -> 1020     raise ValueError(e.message)
#    1021
#    1022   # Record the current Python stack trace as the creating stacktrace of this
#
# ValueError: Exception encountered when calling layer "max_pooling2d_105" (type MaxPooling2D).
#
# Negative dimension size caused by subtracting 2 from 1 for '{{node max_pooling2d_105/MaxPool}} = MaxPool[T=DT_FLOAT, data_format="NHWC", explicit_paddings=[], ksize=[1, 2, 2, 1], padding="VALID", strides=[1, 2, 2, 1]](Placeholder)' with input shapes: [?,1,1,1024].
#
# Call arguments received by layer "max_pooling2d_105" (type MaxPooling2D):
#   • inputs=tf.Tensor(shape=(None, 1, 1, 1024), dtype=float32)

# %%
import os
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout


# 데이터 로드 및 전처리
data_dir = '/content/shapes/shapes'
batch_size = 32
img_height = 180
img_width = 180

train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)
train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training')

validation_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation')

model = Sequential([
    # 첫 번째 컨볼루션 블록
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)),
    MaxPooling2D(2, 2),

    # 두 번째 컨볼루션 블록
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    # 세 번째 컨볼루션 블록
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    # 네 번째 컨볼루션 블록
    Conv2D(256, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    # 네 번째 컨볼루션 블록
    Conv2D(512, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    # Flatten 및 완전 연결 레이어
    Flatten(),
    Dense(512, activation='relu'),
    Dense(3, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 모델 훈련 및 평가
history = model.fit(train_generator, epochs=50, batch_size=48, validation_data=validation_generator)

# 모델 저장 (선택적)
model.save('shapes_model_deeper.h5')
# Out:
# Found 240 images belonging to 3 classes.
# Found 60 images belonging to 3 classes.
# Epoch 1/50
# 8/8 [==============================] - 3s 97ms/step - loss: 1.4785 - accuracy: 0.2792 - val_loss: 1.0981 - val_accuracy: 0.3333
# Epoch 2/50
# 8/8 [==============================] - 1s 75ms/step - loss: 1.1017 - accuracy: 0.3292 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 3/50
# 8/8 [==============================] - 1s 83ms/step - loss: 1.0990 - accuracy: 0.3333 - val_loss: 1.0985 - val_accuracy: 0.3333
# Epoch 4/50
# 8/8 [==============================] - 1s 73ms/step - loss: 1.0990 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 5/50
# 8/8 [==============================] - 1s 80ms/step - loss: 1.0988 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 6/50
# 8/8 [==============================] - 1s 61ms/step - loss: 1.0989 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 7/50
# 8/8 [==============================] - 1s 62ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0985 - val_accuracy: 0.3333
# Epoch 8/50
# 8/8 [==============================] - 1s 61ms/step - loss: 1.0991 - accuracy: 0.3333 - val_loss: 1.0984 - val_accuracy: 0.3333
# Epoch 9/50
# 8/8 [==============================] - 1s 62ms/step - loss: 1.0985 - accuracy: 0.3333 - val_loss: 1.0984 - val_accuracy: 0.3333
# Epoch 10/50
# 8/8 [==============================] - 1s 62ms/step - loss: 1.0985 - accuracy: 0.3333 - val_loss: 1.0982 - val_accuracy: 0.3333
# Epoch 11/50
# 8/8 [==============================] - 1s 62ms/step - loss: 1.0981 - accuracy: 0.3333 - val_loss: 1.0972 - val_accuracy: 0.3333
# Epoch 12/50
# 8/8 [==============================] - 1s 64ms/step - loss: 1.0956 - accuracy: 0.3417 - val_loss: 1.0893 - val_accuracy: 0.3500
# Epoch 13/50
# 8/8 [==============================] - 1s 61ms/step - loss: 1.0861 - accuracy: 0.3958 - val_loss: 1.0715 - val_accuracy: 0.4500
# Epoch 14/50
# 8/8 [==============================] - 1s 61ms/step - loss: 1.0373 - accuracy: 0.4500 - val_loss: 0.9407 - val_accuracy: 0.5500
# Epoch 15/50
# 8/8 [==============================] - 1s 64ms/step - loss: 0.9358 - accuracy: 0.5417 - val_loss: 0.8310 - val_accuracy: 0.5833
# Epoch 16/50
# 8/8 [==============================] - 1s 62ms/step - loss: 0.8487 - accuracy: 0.6417 - val_loss: 0.7638 - val_accuracy: 0.7000
# Epoch 17/50
# 8/8 [==============================] - 1s 62ms/step - loss: 0.6621 - accuracy: 0.7292 - val_loss: 0.4512 - val_accuracy: 0.8333
# Epoch 18/50
# 8/8 [==============================] - 1s 63ms/step - loss: 0.3974 - accuracy: 0.8458 - val_loss: 0.3793 - val_accuracy: 0.8667
# Epoch 19/50
# 8/8 [==============================] - 1s 62ms/step - loss: 0.3222 - accuracy: 0.9000 - val_loss: 0.2258 - val_accuracy: 0.9167
# Epoch 20/50
# 8/8 [==============================] - 1s 64ms/step - loss: 0.2615 - accuracy: 0.9125 - val_loss: 0.2056 - val_accuracy: 0.9500
# Epoch 21/50
# 8/8 [==============================] - 1s 61ms/step - loss: 0.1711 - accuracy: 0.9292 - val_loss: 0.3942 - val_accuracy: 0.8500
# Epoch 22/50
# 8/8 [==============================] - 1s 62ms/step - loss: 0.1836 - accuracy: 0.9458 - val_loss: 0.2423 - val_accuracy: 0.8833
# Epoch 23/50
# 8/8 [==============================] - 1s 64ms/step - loss: 0.0879 - accuracy: 0.9667 - val_loss: 0.2468 - val_accuracy: 0.9167
# Epoch 24/50
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0503 - accuracy: 0.9750 - val_loss: 0.2046 - val_accuracy: 0.9333
# Epoch 25/50
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0230 - accuracy: 0.9958 - val_loss: 0.2192 - val_accuracy: 0.9000
# Epoch 26/50
# 8/8 [==============================] - 1s 86ms/step - loss: 0.0233 - accuracy: 0.9958 - val_loss: 0.2108 - val_accuracy: 0.9333
# Epoch 27/50
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0123 - accuracy: 0.9958 - val_loss: 0.2035 - val_accuracy: 0.9167
# Epoch 28/50
# 8/8 [==============================] - 1s 62ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.2455 - val_accuracy: 0.9167
# Epoch 29/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2419 - val_accuracy: 0.9500
# Epoch 30/50
# 8/8 [==============================] - 1s 63ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2469 - val_accuracy: 0.9500
# Epoch 31/50
# 8/8 [==============================] - 1s 63ms/step - loss: 8.5675e-04 - accuracy: 1.0000 - val_loss: 0.2625 - val_accuracy: 0.9500
# Epoch 32/50
# 8/8 [==============================] - 1s 62ms/step - loss: 6.6799e-04 - accuracy: 1.0000 - val_loss: 0.2690 - val_accuracy: 0.9500
# Epoch 33/50
# 8/8 [==============================] - 1s 61ms/step - loss: 3.5998e-04 - accuracy: 1.0000 - val_loss: 0.2656 - val_accuracy: 0.9500
# Epoch 34/50
# 8/8 [==============================] - 1s 62ms/step - loss: 6.2094e-04 - accuracy: 1.0000 - val_loss: 0.2624 - val_accuracy: 0.9500
# Epoch 35/50
# 8/8 [==============================] - 1s 74ms/step - loss: 9.4678e-04 - accuracy: 1.0000 - val_loss: 0.2658 - val_accuracy: 0.9500
# Epoch 36/50
# 8/8 [==============================] - 1s 64ms/step - loss: 6.3044e-04 - accuracy: 1.0000 - val_loss: 0.2791 - val_accuracy: 0.9500
# Epoch 37/50
# 8/8 [==============================] - 1s 61ms/step - loss: 2.2304e-04 - accuracy: 1.0000 - val_loss: 0.2795 - val_accuracy: 0.9500
# Epoch 38/50
# 8/8 [==============================] - 1s 66ms/step - loss: 2.5305e-04 - accuracy: 1.0000 - val_loss: 0.2805 - val_accuracy: 0.9500
# Epoch 39/50
# 8/8 [==============================] - 1s 61ms/step - loss: 2.2451e-04 - accuracy: 1.0000 - val_loss: 0.2833 - val_accuracy: 0.9500
# Epoch 40/50
# 8/8 [==============================] - 1s 62ms/step - loss: 1.9155e-04 - accuracy: 1.0000 - val_loss: 0.2855 - val_accuracy: 0.9500
# Epoch 41/50
# 8/8 [==============================] - 1s 61ms/step - loss: 2.1466e-04 - accuracy: 1.0000 - val_loss: 0.2862 - val_accuracy: 0.9500
# Epoch 42/50
# 8/8 [==============================] - 1s 63ms/step - loss: 1.8289e-04 - accuracy: 1.0000 - val_loss: 0.2884 - val_accuracy: 0.9500
# Epoch 43/50
# 8/8 [==============================] - 1s 62ms/step - loss: 1.3024e-04 - accuracy: 1.0000 - val_loss: 0.2888 - val_accuracy: 0.9500
# Epoch 44/50
# 8/8 [==============================] - 1s 62ms/step - loss: 1.1836e-04 - accuracy: 1.0000 - val_loss: 0.2880 - val_accuracy: 0.9500
# Epoch 45/50
# 8/8 [==============================] - 1s 82ms/step - loss: 1.5431e-04 - accuracy: 1.0000 - val_loss: 0.2893 - val_accuracy: 0.9500
# Epoch 46/50
# 8/8 [==============================] - 1s 71ms/step - loss: 2.1209e-04 - accuracy: 1.0000 - val_loss: 0.2916 - val_accuracy: 0.9500
# Epoch 47/50
# 8/8 [==============================] - 1s 74ms/step - loss: 1.2858e-04 - accuracy: 1.0000 - val_loss: 0.2923 - val_accuracy: 0.9500
# Epoch 48/50
# 8/8 [==============================] - 1s 62ms/step - loss: 8.0420e-05 - accuracy: 1.0000 - val_loss: 0.2935 - val_accuracy: 0.9500
# Epoch 49/50
# 8/8 [==============================] - 1s 72ms/step - loss: 1.1096e-04 - accuracy: 1.0000 - val_loss: 0.2945 - val_accuracy: 0.9500
# Epoch 50/50
# 8/8 [==============================] - 1s 63ms/step - loss: 1.1589e-04 - accuracy: 1.0000 - val_loss: 0.2935 - val_accuracy: 0.9500
